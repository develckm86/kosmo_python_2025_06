# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

#명시적 대기 : 어떤 요소가 나타날때 까지 대기 
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as ES

driver=webdriver.Chrome()
url="https://www.youtube.com/"
driver.get(url)
driver.implicitly_wait(10) #암시적대기:dom이 로드될때까지 기다리는 것 
search=driver.find_element(By.CSS_SELECTOR,"input#search")
search.send_keys("곽튜브")
search.send_keys(Keys.ENTER)

driver.implicitly_wait(10) 
mainLink=driver.find_element(By.ID,"main-link")
mainLink.click()
driver.implicitly_wait(10) 
#동영상 탭
tab=driver.find_element(By.CSS_SELECTOR,".yt-tab-shape-wiz--host-clickable:nth-child(2)")
tab.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[1], line 14
#      12 driver.get(url)
#      13 driver.implicitly_wait(10) #암시적대기:dom이 로드될때까지 기다리는 것
# ---> 14 search=driver.find_element(By.CSS_SELECTOR,"input#search")
#      15 search.send_keys("곽튜브")
#      16 search.send_keys(Keys.ENTER)
#
# File ~/VsProjects/kosmo_python_2025_06/.venv/lib/python3.14/site-packages/selenium/webdriver/remote/webdriver.py:802, in WebDriver.find_element(self, by, value)
#     799         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     800     return elements[0]
# --> 802 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/VsProjects/kosmo_python_2025_06/.venv/lib/python3.14/site-packages/selenium/webdriver/remote/webdriver.py:432, in WebDriver.execute(self, driver_command, params)
#     429 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     431 if response:
# --> 432     self.error_handler.check_response(response)
#     433     response["value"] = self._unwrap_value(response.get("value", None))
#     434     return response
#
# File ~/VsProjects/kosmo_python_2025_06/.venv/lib/python3.14/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"input#search"}
#   (Session info: chrome=143.0.7499.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 0   chromedriver                        0x00000001050aad7c cxxbridge1$str$ptr + 3028012
# 1   chromedriver                        0x00000001050a2c3c cxxbridge1$str$ptr + 2994924
# 2   chromedriver                        0x0000000104b9eb1c _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74196
# 3   chromedriver                        0x0000000104be59d8 _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 364688
# 4   chromedriver                        0x0000000104c26978 _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 630832
# 5   chromedriver                        0x0000000104bda17c _RNvCsgXDX2mvAJAg_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 317492
# 6   chromedriver                        0x000000010506f2cc cxxbridge1$str$ptr + 2783612
# 7   chromedriver                        0x0000000105072a30 cxxbridge1$str$ptr + 2797792
# 8   chromedriver                        0x000000010504f560 cxxbridge1$str$ptr + 2653200
# 9   chromedriver                        0x00000001050732a0 cxxbridge1$str$ptr + 2799952
# 10  chromedriver                        0x000000010503ff30 cxxbridge1$str$ptr + 2590176
# 11  chromedriver                        0x00000001050921b8 cxxbridge1$str$ptr + 2926696
# 12  chromedriver                        0x0000000105092338 cxxbridge1$str$ptr + 2927080
# 13  chromedriver                        0x00000001050a2894 cxxbridge1$str$ptr + 2993988
# 14  libsystem_pthread.dylib             0x0000000186077c0c _pthread_start + 136
# 15  libsystem_pthread.dylib             0x0000000186072b80 thread_start + 8

# %%
# import time

# time.sleep(2) 

# while True :
#     prevHeight=driver.execute_script("return document.documentElement.scrollHeight") 
#     driver.execute_script("window.scrollTo(0,document.documentElement.scrollHeight)")
#     time.sleep(2)
#     nowHeight=driver.execute_script("return document.documentElement.scrollHeight") 
#     if nowHeight == prevHeight :
#         break
   

# 맨 끝인 것을 검사하는 방법 2가지
# 창의 전체 길이가 변화가 없는지 검사 (쉬운맛 : 인터넷!!)
# 로딩된 컨텐츠의 길이가 변화가 없는지 검사 (인터넷 x,연산시간이 줄어든다.)

# %%
loadingBlock="#contents>.style-scope.ytd-rich-grid-renderer:nth-child(1)"
WebDriverWait(driver,10).until(ES.presence_of_element_located((By.CSS_SELECTOR,loadingBlock)))

body=driver.find_element(By.TAG_NAME,"body")
while True :
    blockList=driver.find_elements(By.CSS_SELECTOR,"#contents>.style-scope.ytd-rich-grid-renderer") #12
    prevLen=(len(blockList))
    body.send_keys(Keys.END)
    loadingBlock=f"#contents>.style-scope.ytd-rich-grid-renderer:nth-child({prevLen+1})"
    print(loadingBlock)
    try :
        WebDriverWait(driver,10).until(ES.presence_of_element_located((By.CSS_SELECTOR,loadingBlock)))
    except :
        print("다음 요소가 없습니다.") 
        break

    # 다음요소가 없으면 종료되기 때문에 필요가 없어짐
    # blockList=driver.find_elements(By.CSS_SELECTOR,"#contents>.style-scope.ytd-rich-grid-renderer") #13
    # nowLen=(len(blockList))

    # if prevLen == nowLen :
    #     break
# Out:
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(2)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(18)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(34)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(49)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(64)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(79)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(94)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(109)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(124)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(139)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(154)
# #contents>.style-scope.ytd-rich-grid-renderer:nth-child(163)
# 다음 요소가 없습니다.
