# %%
a=10
a
# Out:
# 10

# %%
a,b=10,20
print(a,b)
# Out:
# 10 20

# %%
# a,b,c=10
a,b,c=10,20,30
print(a,b,c)
# Out:
# 10 20 30

# %%
a,*b=[10,20,30]
print(a,b)
# Out:
# 10 [20, 30]

# %%
a,b=10,20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %%
a,b=10,20
a=b
b=a
print(a,b)
a,b=10,20
temp=a
a=b
b=temp
print(a,b)
# Out:
# 20 20
# 20 10

# %%
a
print(a, type(a))
a=None
print(a, type(a))

# a=null  # 오류
# a=Undefined  # 오류
# Out:
# None <class 'NoneType'>
# None <class 'NoneType'>

# %%
a
print(a is None)
print(a == None)
a=10
print(a is None)
print(a is not None)
# Out:
# False
# False
# False
# True
